# %% [markdown]
# ## Importing the libraries and data frames

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

df = pd.read_csv(r"C:\Users\pc\Desktop\Analysis project files\salary_data.csv") 
df
# Out:
#             country_name continent_name wage_span  median_salary  \
# 0            Afghanistan           Asia   Monthly     853.740000
# 1          Aland Islands         Europe   Monthly    3319.240000
# 2                Albania         Europe   Monthly     832.840000
# 3                Algeria         Africa   Monthly    1148.840000
# 4         American Samoa        Oceania   Monthly    1390.000000
# ..                   ...            ...       ...            ...
# 216  Virgin Islands (US)  North America   Monthly    2380.000000
# 217       Western Sahara         Africa   Monthly     908.560000
# 218                Yemen           Asia   Monthly     120.980000
# 219               Zambia         Africa   Monthly       0.261335
# 220             Zimbabwe         Africa   Monthly     555.402040
#
#      average_salary  lowest_salary  highest_salary
# 0       1001.150000     252.530000     4460.970000
# 1       3858.350000     972.520000    17124.740000
# ...

# %% [markdown]
# ## Loading starting 5 coloumns and rows

# %%
df.head()
# Out:
#      country_name continent_name wage_span  median_salary  average_salary  \
# 0     Afghanistan           Asia   Monthly         853.74         1001.15
# 1   Aland Islands         Europe   Monthly        3319.24         3858.35
# 2         Albania         Europe   Monthly         832.84          956.92
# 3         Algeria         Africa   Monthly        1148.84         1308.81
# 4  American Samoa        Oceania   Monthly        1390.00         1570.00
#
#    lowest_salary  highest_salary
# 0         252.53         4460.97
# 1         972.52        17124.74
# 2         241.22         4258.49
# 3         330.11         5824.18
# 4         400.00         6980.00

# %% [markdown]
# ## Finding out if any null value Through boolean expression

# %%
df.isnull()
# Out:
#      country_name  continent_name  wage_span  median_salary  average_salary  \
# 0           False           False      False          False           False
# 1           False           False      False          False           False
# 2           False           False      False          False           False
# 3           False           False      False          False           False
# 4           False           False      False          False           False
# ..            ...             ...        ...            ...             ...
# 216         False           False      False          False           False
# 217         False           False      False          False           False
# 218         False           False      False          False           False
# 219         False           False      False          False           False
# 220         False           False      False          False           False
#
#      lowest_salary  highest_salary
# ...

# %%
df.isnull().sum()
# Out:
# country_name      0
# continent_name    0
# wage_span         0
# median_salary     0
# average_salary    0
# lowest_salary     0
# highest_salary    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Finding out if any duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 216    False
# 217    False
# 218    False
# 219    False
# 220    False
# Length: 221, dtype: bool

# %% [markdown]
# ## Converting the float values to Integer vlalues

# %%
df['median_salary'] = df['median_salary'].astype(int)
df

df['average_salary'] = df['average_salary'].astype(int)
df

df['lowest_salary'] = df['lowest_salary'].astype(int)
df

df['highest_salary'] = df['highest_salary'].astype(int)
df
# Out:
#             country_name continent_name wage_span  median_salary  \
# 0            Afghanistan           Asia   Monthly            853
# 1          Aland Islands         Europe   Monthly           3319
# 2                Albania         Europe   Monthly            832
# 3                Algeria         Africa   Monthly           1148
# 4         American Samoa        Oceania   Monthly           1390
# ..                   ...            ...       ...            ...
# 216  Virgin Islands (US)  North America   Monthly           2380
# 217       Western Sahara         Africa   Monthly            908
# 218                Yemen           Asia   Monthly            120
# 219               Zambia         Africa   Monthly              0
# 220             Zimbabwe         Africa   Monthly            555
#
#      average_salary  lowest_salary  highest_salary
# 0              1001            252            4460
# 1              3858            972           17124
# ...

# %% [markdown]
# ## Frequency of Countries in each Continent

# %%
df['continent_name'].value_counts().plot(kind='bar', color = 'lightblue')
plt.xlabel('Continent')
plt.ylabel('Frequency')
plt.title('Frequency of Countries in Each Continent')
plt.show()

# %% [markdown]
# ## Top 10 countries with Highest salaries

# %%
top_10_countries = df.sort_values(by='highest_salary', ascending=False).head(10)


plt.figure(figsize=(7, 6))
plt.bar(top_10_countries['country_name'], top_10_countries['highest_salary'], color='lightgreen')
plt.xlabel('Country')
plt.ylabel('Highest Salary')
plt.title('Top 10 Countries with Highest Salaries')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 countries with lowest salaries

# %%
bottom_10_countries = df.sort_values(by='highest_salary', ascending=True).head(10)


plt.figure(figsize=(7, 6))
plt.bar(bottom_10_countries['country_name'], top_10_countries['highest_salary'], color ='red')
plt.xlabel('Country')
plt.ylabel('Highest Salary')
plt.title('Top 10 Countries with Lowest Salaries')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 countries with Average salaries

# %%
top_10_countries = df.sort_values(by='average_salary', ascending=False).head(10)


plt.figure(figsize=(8, 6))
plt.barh(top_10_countries['country_name'], top_10_countries['average_salary'], color='lightgreen')
plt.xlabel('Country')
plt.ylabel('average_salary')
plt.title('top 10 Countries with average Salaries')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bottom 10 countries with Average salaries

# %%
bottom_10_countries = df.sort_values(by='average_salary', ascending=True).head(10)


plt.figure(figsize=(8, 6))
plt.barh(bottom_10_countries['country_name'], bottom_10_countries['average_salary'], color= 'red')
plt.ylabel('Country')
plt.xlabel('average_salary')
plt.title('bottom 10 Countries with average Salaries')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
